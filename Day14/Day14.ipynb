# %% [markdown]
# # ML
# - why do we need to learn ML
# - waht is ML and how it works

# %%
import pandas as pd

# %%
df=pd.read_csv('example.csv')
df
# Out:
#    Age  InsuranceCost
# 0   22           2500
# 1   25           2800
# 2   28           3200
# 3   30           3500
# 4   35           4200
# 5   40           5000
# 6   45           5800
# 7   50           6500
# 8   55           7200
# 9   60           8000

# %%
import matplotlib.pyplot as plt
import numpy as np;
plt.scatter(df['Age'],df['InsuranceCost'])
m,c=np.polyfit(df['Age'],df['InsuranceCost'],1)
plt.plot(df['Age'],m*df['Age']+c)

# %%
from sklearn.model_selection import train_test_split
x=df['Age']
y=df['InsuranceCost']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
x_train
# Out:
# 6    45
# 0    22
# 2    28
# 4    35
# 5    40
# 7    50
# 9    60
# 8    55
# Name: Age, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

model=LinearRegression()

x=x.to_numpy().reshape(-1,1)
model.fit(x,y)
# Out:
# LinearRegression()

# %%
y_pred=model.predict([[22]])
y_pred
# Out:
# array([2368.01026958])
