# %% [markdown]
# # DL
#
# ## ML
# - Raw Data -- features -- model -- decision
#
# ## DL
# - Raw Data -- Neural Networks -- features -- decision
# - Deep learning automatically learns features from raw Data.
# - Human Brain == Neural Networks
# - Experience == Training Data
#
# ### Where can we use DL
# - if data is unstructured
# - patterns are clmplex
#   - face unlock
#   - voice assistance (Alexa, Siri)
#   - Google Translate
#   - self driving cars
#   - medical image diagnosis
#   - Chatbots
#
# ---
#
# ### Biological Neuron vs Artificial Neuron
#
# - Neuron : neuron is decision Making Unit
# - Parts of Neuron
#   1. Receives Signals (data)
#   2. Process them
#   3. Decide weather to pass the signal or not.
#
#
# - why computer needs a neuron model?
#     1. Why Deeplearning?
#     2. Where Deep Learning is used?
#     3. What is neuron
#     4. why computer needs a neuron model?
#
#
# x = a+b
# 1. inputs : x1,x2,x3,......,xn
# 2. Weights -- (importance input)
# 3. sum of inputs (x1*w1 + x2*w2 + x3*w4+ ........ + xn*wn)
# 4.
# 5. Activaion Function
#
# x1=9
# x2=7
# bias=-1
# w1=2
# w2=1
# sum=(x1*w1 + x2*w2 + bias) ==> (9*2 + 7*1 -1) ==>24
#
# 0-1 > if 0.5>1   0.5<0
# Neuron multiplies inputs with importance,
# add bias and passess through activation function
#
# why activation function is needed?
# - without activation function the outputs is just a number, np decision
# - activation function will convert number (signal) into decision.
#
# What does artificial neuron do?
#
# Perceptron : It is a single neuron model
#
# binary classification :
#
#
#
#
# sigmoid :  0.5>  --> 1
#            0.5<  --> 0
#
#
# sigmoid : if output is close to 1
