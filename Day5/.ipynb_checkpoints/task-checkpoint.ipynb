# %%
import pandas as pd

# %%
df=pd.read_csv("task.csv")
df
# Out:
#       user_id      age     salary department   join_date       city  \
# 0      user_0       -5     ₹50000         HR  2020/12/01      DELHI
# 1       U1001       30      45000    Finance  15/02/2021      Delhi
# 2       U1002       30      25000         HR         NaN      Delhi
# 3         NaN  unknown        NaN         HR     invalid  Hyderabad
# 4         NaN      NaN  120000.75         IT         NaN      DELHI
# ..        ...      ...        ...        ...         ...        ...
# 995       NaN       60     ₹50000         HR  15/02/2021      DELHI
# 996     U1996      NaN        NaN         IT  15/02/2021     Mumbai
# 997  user_997  unknown      25000         HR     invalid     Mumbai
# 998     U1998       -5      25000        NaN  15/02/2021  Bangalore
# 999       NaN       30      45000         HR  2022-01-15  Hyderabad
#
#     performance_score experience_years is_active
# 0                   3             five      True
# 1                   3                1       yes
# 2           excellent               10     False
# 3           excellent                5       yes
# 4                 NaN               -1     False
# ..                ...              ...       ...
# 995                 2             five       NaN
# 996               NaN                5        no
# 997                 3                5      True
# 998                 1                0      True
# 999         excellent             five        no
#
# [1000 rows x 9 columns]

# %% [markdown]
# ### 1

# %%
df.shape
# Out:
# (1000, 9)

# %%
df.columns
# Out:
# Index(['user_id', 'age', 'salary', 'department', 'join_date', 'city',
#        'performance_score', 'experience_years', 'is_active'],
#       dtype='object')

# %%
df.dtypes
# Out:
# user_id              object
# age                  object
# salary               object
# department           object
# join_date            object
# city                 object
# performance_score    object
# experience_years     object
# is_active            object
# dtype: object

# %% [markdown]
# ### 2

# %%
df.isnull().mean()*100
# Out:
# user_id              5.10
# age                  1.14
# salary               3.11
# department           1.41
# join_date            2.19
# city                 1.49
# performance_score    1.01
# experience_years     1.27
# is_active            2.00
# dtype: float64

# %% [markdown]
# ### 3

# %%
df.apply(lambda col: col.map(type).nunique())
# Out:
# user_id              2
# age                  1
# salary               2
# department           2
# join_date            2
# city                 2
# performance_score    2
# experience_years     2
# is_active            2
# dtype: int64

# %% [markdown]
# ### 4

# %%
df['user_id'].replace('', pd.NA, inplace=True)
df['user_id'] = df['user_id'].str.upper()

df.sample(10)
# Out:
#       user_id    age     salary department   join_date       city  \
# 506       NaN   45.0      45000         HR     invalid      DELHI
# 626       NaN    NaN      45000         HR         NaN        NaN
# 313       NaN   18.0      45000      Sales     invalid     Mumbai
# 23      U1023   60.0      78000      Sales     invalid  Hyderabad
# 915     U1915    NaN  120000.75         HR  2022-01-15      Delhi
# 547     U1547  200.0      45000         HR     invalid      Delhi
# 552       NaN   60.0      45000        NaN     invalid      DELHI
# 479  USER_479   30.0      45000         HR     invalid  Bangalore
# 199     U1199   -5.0      25000         HR  15/02/2021  Bangalore
# 346  USER_346  200.0      25000         HR         NaN      DELHI
#
#     performance_score experience_years is_active
# 506                 3             five        no
# 626              poor                1      True
# 313               NaN               10        no
# 23                NaN                0     False
# 915                 5                1     False
# 547                 1              NaN      True
# 552              poor               10        no
# 479              poor                0        no
# 199                 4             five     False
# 346                 2                1       NaN

# %% [markdown]
# ## 5

# %%
df['age'] = pd.to_numeric(df['age'])
df['age']
# Out:
# 0      -5.0
# 1      30.0
# 2      30.0
# 3       NaN
# 4       NaN
#        ...
# 995    60.0
# 996     NaN
# 997     NaN
# 998    -5.0
# 999    30.0
# Name: age, Length: 1000, dtype: float64

# %% [markdown]
# ## 6

# %%
df['salary'].replace("₹50000","50000",inplace=True)
df['salary']= pd.to_numeric(df['salary'])
df.sample(10)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_21104\1852201875.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['salary'].replace("₹50000","50000",inplace=True)
#       user_id   age     salary department   join_date       city  \
# 727     U1727   NaN   78000.00    Finance     invalid      Delhi
# 663       NaN  45.0   78000.00         HR  2020/12/01        NaN
# 626       NaN   NaN   45000.00         HR         NaN        NaN
# 109       NaN  18.0        NaN    Finance  15/02/2021     mumbai
# 393       NaN  18.0   50000.00         IT         NaN  Bangalore
# 268  USER_268   NaN  120000.75      Sales         NaN  Hyderabad
# 569       NaN  18.0        NaN        it   2022-01-15     mumbai
# 635  USER_635  45.0   50000.00        it   2020/12/01     mumbai
# 912     U1912  60.0   50000.00    Finance  15/02/2021      DELHI
# 856  USER_856  30.0   78000.00        NaN         NaN     Mumbai
#
#     performance_score experience_years is_active
# 727                 4                3       NaN
# 663                 1              NaN        no
# 626              poor                1      True
# 109                 5                3       yes
# 393              poor               -1       NaN
# 268                 2              NaN      True
# 569                 1              NaN     False
# 635                 5                3      True
# 912                 1              NaN      True
# 856                 2                5       NaN

# %% [markdown]
# ## 7
